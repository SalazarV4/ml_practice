# %%
import pandas as pd
from sklearn.datasets import fetch_openml

# %%
X, y = fetch_openml("credit-g",
             return_X_y=True,
             as_frame=True,
             version=1)
df = pd.concat([X,y], axis=1)

# %%
df.to_csv("../data/credit_score.csv")
